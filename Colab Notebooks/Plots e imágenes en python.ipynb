# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.linspace(0,10,100)
Y = np.sin(X)
plt.plot(X,Y)
Z = np.cos(X)
plt.plot(X,Z)
plt.legend(['Sinus','Cosinus'])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0,50,1)
y = 3*x
plt.plot(x,y)
plt.title("Draw a line")
plt.xlabel("x - axis")
plt.xlim(0,50)
plt.ylabel("y - axis")
plt.ylim(0,160)
plt.grid('on')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(1,3,5)
y = np.zeros(len(x))
for i in range (0,len(x)):
  if i<=2:
    y[i] = 2*x[i]
  else:
    y[i] = 10 - 3*x[i]
print(x)
print(y)
plt.plot(x,y)
plt.xlabel("x - axis")
plt.xlim(1,3)
plt.ylabel("y - axis")
plt.ylim(1,4)
plt.title("Triangle function")
plt.show()
# Out:
# [1.  1.5 2.  2.5 3. ]
# [2.  3.  4.  2.5 1. ]

# %%
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files

#uploaded = files.upload()

lista = list(open("test.txt","r"))
x = np.array([int(row[0]) for row in lista])
y = np.array([int(row[2]) for row in lista])
print(x,y)
plt.plot(x,y)
plt.xlabel("x - axis")
plt.xlim(1,3)
plt.ylabel("y - axis")
plt.ylim(1,4)
plt.title("Triangle function")
plt.show()
# Out:
# [1 2 3] [2 4 1]

# %%
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files
import pandas as pd

#uploaded = files.upload()
df = pd.read_csv('fdata.txt', sep=',', parse_dates=True, index_col=0)
df.plot()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(10,31,10)
y1 = np.array([2*x[i] if x[i]<=20 else 100 - 3*x[i] for i in range(0,len(x))])
y2 = np.array([70 - 3*x[i] if x[i]<=20 else -30 + 2*x[i] for i in range(0,len(x))])
print(x,y1,y2)
plt.plot(x,y1)
plt.plot(x,y2)
plt.xlabel("x - axis")
plt.ylabel("y - label")
plt.legend("Double triangle plot")
plt.xlim(10,30)
plt.ylim(10,40)
plt.legend(['y1','y2'])
plt.show()
# Out:
# [10 20 30] [20 40 10] [40 10 30]

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(10,31,10)
y1 = np.array([2*x[i] if x[i]<=20 else 100 - 3*x[i] for i in range(0,len(x))])
y2 = np.array([70 - 3*x[i] if x[i]<=20 else -30 + 2*x[i] for i in range(0,len(x))])
print(x,y1,y2)
plt.plot(x,y1,'b',linewidth = 3)
plt.plot(x,y2,'r',linewidth = 3)
plt.xlabel("x - axis")
plt.ylabel("y - label")
plt.legend("Double triangle plot")
plt.xlim(10,30)
plt.ylim(10,40)
plt.legend(['y1','y2'])
plt.show()
# Out:
# [10 20 30] [20 40 10] [40 10 30]

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(10,31,10)
y1 = np.array([2*x[i] if x[i]<=20 else 100 - 3*x[i] for i in range(0,len(x))])
y2 = np.array([70 - 3*x[i] if x[i]<=20 else -30 + 2*x[i] for i in range(0,len(x))])
print(x,y1,y2)
plt.plot(x,y1,'bo:',linewidth = 2)
plt.plot(x,y2,'r*-',linewidth = 2)
plt.xlabel("x - axis")
plt.ylabel("y - label")
plt.legend("Double triangle plot")
plt.xlim(10,30)
plt.ylim(10,40)
plt.legend(['y1','y2'])
plt.show()
# Out:
# [10 20 30] [20 40 10] [40 10 30]

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(10,31,10)
y1 = np.array([2*x[i] if x[i]<=20 else 100 - 3*x[i] for i in range(0,len(x))])
y2 = np.array([70 - 3*x[i] if x[i]<=20 else -30 + 2*x[i] for i in range(0,len(x))])
print(x,y1,y2)
plt.plot(x,y1,'bo')
plt.plot(x,y2,'r*')
plt.xlabel("x - axis")
plt.ylabel("y - label")
plt.legend("Double triangle plot")
plt.xlim(10,30)
plt.ylim(10,40)
plt.legend(['y1','y2'])
plt.show()
# Out:
# [10 20 30] [20 40 10] [40 10 30]

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.subplot(2,1,1)
plt.xticks(())
plt.yticks(())
plt.subplot(2,3,4)
plt.xticks(())
plt.yticks(())
plt.subplot(2,3,5)
plt.xticks(())
plt.yticks(())
plt.subplot(2,3,6)
plt.xticks(())
plt.yticks(())
plt.show()
