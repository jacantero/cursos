# %%
import numpy as np

# %%
x = 3
print(type(x)) # Prints "<class 'int'>"
print(x)       # Prints "3"
print(x + 1)   # Addition; prints "4"
print(x - 1)   # Subtraction; prints "2"
print(x * 2)   # Multiplication; prints "6"
print(x ** 2)  # Exponentiation; prints "9"
# Out:
# <class 'int'>
# 3
# 4
# 2
# 6
# 9

# %%
xs = [3, 1, 2]    # Create a list
print(xs, xs[2])  # Prints "[3, 1, 2] 2"
xs[-3]     # Negative indices count from the end of the list; prints "2"
# Out:
# [3, 1, 2] 2
# 3

# %%
xs = [3, 1, 2]    # Create a list
print (xs)
xs.clear()
print (xs)
# Out:
# [3, 1, 2]
# []

# %%
xs = [3, 1, 2]    # Create a list
print(xs, xs[2])  # Prints "[3, 1, 2] 2"
del xs[0]
print(xs)
# Out:
# [3, 1, 2] 2
# [1, 2]

# %%
t = ([4,3,2],[5],[6])
x = [1,2,3]
t[0].extend([0,0,0])
t[0]
del t[0][0:3]
t[0]
# Out:
# [0, 0, 0]

# %%
t = 12345,54321,' hello!'
x,y,z = t
print(x,y,z)
# Out:
# 12345 54321  hello!

# %%
d = {'jack' : 1, 2 : 0}
d[3] = 1
d.values()
# Out:
# dict_values([1, 0, 1])
