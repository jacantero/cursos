# %%
# The hypothesis testing is a core data analysis actibity behind experimentation, which goal is to determine if two 
# different conditions we have in an experiment have resulted in different impacts

# Library import
import numpy as np
import pandas as pd

from scipy import stats

# %%
# When we do hypothesis testing, we have two statements of interest: the first is our actual explanation, which we call
# the alternative hypothesis, and the second is that the explanation we have is not sufficient, and we call this the null 
# hypothesis. The testing method is to determine whether the null hypothesis is true or not, so if we find there is a 
# difference between groups, the we can reject the null hypothesis and accept our alternative

### Example

# We load our dataset
df = pd.read_csv('datasets/grades.csv')
df.head()
# Out:
#                              student_id  assignment1_grade  \
# 0  B73F2C11-70F0-E37D-8B10-1D20AFED50B1          92.733946
# 1  98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1          86.790821
# 2  D0F62040-CEB0-904C-F563-2F8620916C4E          85.512541
# 3  FFDF2B2C-F514-EF7F-6538-A6A53518E9DC          86.030665
# 4  5ECBEEB6-F1CE-80AE-3164-E45E99473FB4          64.813800
#
#           assignment1_submission  assignment2_grade  \
# 0  2015-11-02 06:55:34.282000000          83.030552
# 1  2015-11-29 14:57:44.429000000          86.290821
# 2  2016-01-09 05:36:02.389000000          85.512541
# 3  2016-04-30 06:50:39.801000000          68.824532
# 4  2015-12-13 17:06:10.750000000          51.491040
#
#           assignment2_submission  assignment3_grade  \
# 0  2015-11-09 02:22:58.938000000          67.164441
# 1  2015-12-06 17:41:18.449000000          69.772657
# 2  2016-01-09 06:39:44.416000000          68.410033
# 3  2016-04-30 17:20:38.727000000          61.942079
# 4  2015-12-14 12:25:12.056000000          41.932832
#
#           assignment3_submission  assignment4_grade  \
# 0  2015-11-12 08:58:33.998000000          53.011553
# 1  2015-12-10 08:54:55.904000000          55.098125
# 2  2016-01-15 20:22:45.882000000          54.728026
# 3  2016-05-12 07:47:16.326000000          49.553663
# 4  2015-12-29 14:25:22.594000000          36.929549
#
#           assignment4_submission  assignment5_grade  \
# 0  2015-11-16 01:21:24.663000000          47.710398
# 1  2015-12-13 17:32:30.941000000          49.588313
# 2  2016-01-11 12:41:50.749000000          49.255224
# 3  2016-05-07 16:09:20.485000000          49.553663
# 4  2015-12-28 01:29:55.901000000          33.236594
#
#           assignment5_submission  assignment6_grade  \
# 0  2015-11-20 13:24:59.692000000          38.168318
# 1  2015-12-19 23:26:39.285000000          44.629482
# 2  2016-01-11 17:31:12.489000000          44.329701
# 3  2016-05-24 12:51:18.016000000          44.598297
# 4  2015-12-29 14:46:06.628000000          33.236594
#
#           assignment6_submission
# 0  2015-11-22 18:31:15.934000000
# 1  2015-12-21 17:07:24.275000000
# 2  2016-01-17 16:24:42.765000000
# 3  2016-05-26 08:09:12.058000000
# 4  2016-01-05 01:06:59.546000000

# %%
# We show the shape of the dataframe
print("There are {} rows and {} columns".format(df.shape[0], df.shape[1]))
# Out:
# There are 2315 rows and 13 columns

# %%
# We segment the data between early finishers (before the end of December 2015) and late finishers
early_finishers=df[pd.to_datetime(df['assignment1_submission']) < '2016']
early_finishers.head()
# Out:
#                              student_id  assignment1_grade  \
# 0  B73F2C11-70F0-E37D-8B10-1D20AFED50B1          92.733946
# 1  98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1          86.790821
# 4  5ECBEEB6-F1CE-80AE-3164-E45E99473FB4          64.813800
# 5  D09000A0-827B-C0FF-3433-BF8FF286E15B          71.647278
# 8  C9D51293-BD58-F113-4167-A7C0BAFCB6E5          66.595568
#
#           assignment1_submission  assignment2_grade  \
# 0  2015-11-02 06:55:34.282000000          83.030552
# 1  2015-11-29 14:57:44.429000000          86.290821
# 4  2015-12-13 17:06:10.750000000          51.491040
# 5  2015-12-28 04:35:32.836000000          64.052550
# 8  2015-12-25 02:29:28.415000000          52.916454
#
#           assignment2_submission  assignment3_grade  \
# 0  2015-11-09 02:22:58.938000000          67.164441
# 1  2015-12-06 17:41:18.449000000          69.772657
# 4  2015-12-14 12:25:12.056000000          41.932832
# 5  2016-01-03 21:05:38.392000000          64.752550
# 8  2015-12-31 01:42:30.046000000          48.344809
#
#           assignment3_submission  assignment4_grade  \
# 0  2015-11-12 08:58:33.998000000          53.011553
# 1  2015-12-10 08:54:55.904000000          55.098125
# 4  2015-12-29 14:25:22.594000000          36.929549
# 5  2016-01-07 08:55:43.692000000          57.467295
# 8  2016-01-05 23:34:02.180000000          47.444809
#
#           assignment4_submission  assignment5_grade  \
# 0  2015-11-16 01:21:24.663000000          47.710398
# 1  2015-12-13 17:32:30.941000000          49.588313
# 4  2015-12-28 01:29:55.901000000          33.236594
# 5  2016-01-11 00:45:28.706000000          57.467295
# 8  2016-01-02 07:48:42.517000000          37.955847
#
#           assignment5_submission  assignment6_grade  \
# 0  2015-11-20 13:24:59.692000000          38.168318
# 1  2015-12-19 23:26:39.285000000          44.629482
# 4  2015-12-29 14:46:06.628000000          33.236594
# 5  2016-01-11 00:54:13.579000000          57.467295
# 8  2016-01-03 21:27:04.266000000          37.955847
#
#           assignment6_submission
# 0  2015-11-22 18:31:15.934000000
# 1  2015-12-21 17:07:24.275000000
# 4  2016-01-05 01:06:59.546000000
# 5  2016-01-20 19:54:46.166000000
# 8  2016-01-19 15:24:31.060000000

# %%
late_finishers=df[pd.to_datetime(df['assignment1_submission']) >= '2016']
late_finishers.head()
# Out:
#                              student_id  assignment1_grade  \
# 2  D0F62040-CEB0-904C-F563-2F8620916C4E          85.512541
# 3  FFDF2B2C-F514-EF7F-6538-A6A53518E9DC          86.030665
# 6  3217BE3F-E4B0-C3B6-9F64-462456819CE4          87.498744
# 7  F1CB5AA1-B3DE-5460-FAFF-BE951FD38B5F          80.576090
# 9  E2C617C2-4654-622C-AB50-1550C4BE42A0          59.270882
#
#           assignment1_submission  assignment2_grade  \
# 2  2016-01-09 05:36:02.389000000          85.512541
# 3  2016-04-30 06:50:39.801000000          68.824532
# 6  2016-03-05 11:05:25.408000000          69.998995
# 7  2016-01-24 18:24:25.619000000          72.518481
# 9  2016-03-06 12:06:26.185000000          59.270882
#
#           assignment2_submission  assignment3_grade  \
# 2  2016-01-09 06:39:44.416000000          68.410033
# 3  2016-04-30 17:20:38.727000000          61.942079
# 6  2016-03-09 07:29:52.405000000          55.999196
# 7  2016-01-27 13:37:12.943000000          65.266633
# 9  2016-03-13 02:07:25.289000000          53.343794
#
#           assignment3_submission  assignment4_grade  \
# 2  2016-01-15 20:22:45.882000000          54.728026
# 3  2016-05-12 07:47:16.326000000          49.553663
# 6  2016-03-16 22:31:24.316000000          50.399276
# 7  2016-01-30 14:34:36.581000000          65.266633
# 9  2016-03-17 07:30:09.241000000          53.343794
#
#           assignment4_submission  assignment5_grade  \
# 2  2016-01-11 12:41:50.749000000          49.255224
# 3  2016-05-07 16:09:20.485000000          49.553663
# 6  2016-03-18 07:19:26.032000000          45.359349
# 7  2016-02-03 22:08:49.002000000          65.266633
# 9  2016-03-20 21:45:56.229000000          42.675035
#
#           assignment5_submission  assignment6_grade  \
# 2  2016-01-11 17:31:12.489000000          44.329701
# 3  2016-05-24 12:51:18.016000000          44.598297
# 6  2016-03-19 10:35:41.869000000          45.359349
# 7  2016-02-16 14:22:23.664000000          65.266633
# 9  2016-03-27 15:55:04.414000000          38.407532
#
#           assignment6_submission
# 2  2016-01-17 16:24:42.765000000
# 3  2016-05-26 08:09:12.058000000
# 6  2016-03-23 14:02:00.987000000
# 7  2016-02-18 08:35:04.796000000
# 9  2016-03-30 20:33:13.554000000

# %%
#Another solution
late_finishers=df[-df.index.isin(early_finishers.index)]
late_finishers.head()

# %%
# We calculate the mean of the early finishers and the late finishers and compare them
print('Early finishers mean {}'.format(early_finishers['assignment1_grade'].mean()))
print('Late finishers mean {}'.format(late_finishers['assignment1_grade'].mean()))
# Out:
# Early finishers mean 74.94728457024303
# Late finishers mean 74.0450648477065

# %%
# We make the student' t-test: "These are the same"(null hypothesis) vs "These are different" (alternative hypothesis)
# When doing hypothesis testing, we have to choose a significance level as a threshold for how much of a chance we're
# willing to accept. This significance level is called alpha, and is usually fixed at 0.05 (5% of probability)

# We use the ttest_ind() function, which does an independent t-test (meaning the populations are not related to each other)
# The results of ttest_index() are the t-statistics and a p-value. The latter value is the probability of our null 
# hypothesis being True

from scipy.stats import ttest_ind

ttest_ind(early_finishers['assignment1_grade'], late_finishers['assignment1_grade'])
# Out:
# Ttest_indResult(statistic=1.322354085372139, pvalue=0.1861810110171455)

# %%
# The probability is of 0.18 (18%), which is greater than our alpha value, so we can't reject the null hypothesis.
# We try to compare both populations for other assignments

# %%
print(ttest_ind(early_finishers['assignment2_grade'], late_finishers['assignment2_grade']))
print(ttest_ind(early_finishers['assignment3_grade'], late_finishers['assignment3_grade']))
print(ttest_ind(early_finishers['assignment4_grade'], late_finishers['assignment4_grade']))
print(ttest_ind(early_finishers['assignment5_grade'], late_finishers['assignment5_grade']))
print(ttest_ind(early_finishers['assignment6_grade'], late_finishers['assignment6_grade']))
# Out:
# Ttest_indResult(statistic=1.2514717608216366, pvalue=0.2108889627004424)
# Ttest_indResult(statistic=1.6133726558705392, pvalue=0.10679998102227865)
# Ttest_indResult(statistic=0.049671157386456125, pvalue=0.960388729789337)
# Ttest_indResult(statistic=-0.05279315545404755, pvalue=0.9579012739746492)
# Ttest_indResult(statistic=-0.11609743352612056, pvalue=0.9075854011989656)

# %%
# P-values are being subtituted by confidence intervalues and bayesian analyses. 
# To a certain extent, this is due to the fact that p-values can give values statistically significant just by chance

# We simulate this by creating a random data frame of 100 columns with 100 numbers
df1=pd.DataFrame([np.random.random(100) for x in range(100)])
df1.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.581311  0.743677  0.574313  0.830782  0.640710  0.038266  0.390913
# 1  0.895667  0.092221  0.388887  0.471189  0.094813  0.336801  0.987982
# 2  0.061380  0.465369  0.877793  0.751639  0.191279  0.735716  0.351122
# 3  0.280769  0.908559  0.923416  0.185500  0.153278  0.062157  0.605002
# 4  0.475410  0.083634  0.330500  0.589319  0.423962  0.232198  0.372335
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.241194  0.970414  0.868899  ...  0.911083  0.224093  0.411807  0.081407
# 1  0.721411  0.196705  0.709043  ...  0.281798  0.049231  0.532779  0.542215
# 2  0.146411  0.042480  0.980769  ...  0.684948  0.652942  0.802162  0.203423
# 3  0.108329  0.049231  0.384284  ...  0.804150  0.341486  0.513475  0.377585
# 4  0.398312  0.248361  0.216580  ...  0.338052  0.227636  0.491099  0.076029
#
#          94        95        96        97        98        99
# 0  0.188717  0.423747  0.443961  0.830691  0.006412  0.501419
# 1  0.581133  0.340511  0.121178  0.678905  0.365520  0.771978
# 2  0.750375  0.184508  0.184437  0.034050  0.846986  0.950061
# 3  0.142065  0.549184  0.578526  0.543612  0.099152  0.046715
# 4  0.473023  0.154670  0.015773  0.023164  0.001579  0.663168
#
# [5 rows x 100 columns]

# %%
# And another one to compare if they are the same
df2=pd.DataFrame([np.random.random(100) for x in range(100)])

# %%
# We create a function for testing the similarity, with a value for alpha of 0.1
def test_columns(alpha=0.1):
    # We keep track of how many differ
    num_diff=0
    for col in df1.columns:
        # We run the ttest over the two dataframes
        teststat,pval=ttest_ind(df1[col], df2[col])
        # We check the pvalue vs the alpha
        if pval<= alpha:
            print("Col {} is statistically significantly different at alpha={}, pval={}".format(col, alpha, pval))
            num_diff=num_diff+1
    # We print some summary stats
    print("Total number different was {}, which is {}%".format(num_diff, float(num_diff)/len(df1.columns)*100))

# We run the test
test_columns()
# Out:
# Col 4 is statistically significantly different at alpha=0.1, pval=0.0827959692286876
# Col 31 is statistically significantly different at alpha=0.1, pval=0.044042416341466134
# Col 51 is statistically significantly different at alpha=0.1, pval=0.007140344318679064
# Col 55 is statistically significantly different at alpha=0.1, pval=0.057978837974823776
# Col 58 is statistically significantly different at alpha=0.1, pval=0.02588626092257888
# Col 59 is statistically significantly different at alpha=0.1, pval=0.07183284825081902
# Col 62 is statistically significantly different at alpha=0.1, pval=0.06675653329457414
# Col 64 is statistically significantly different at alpha=0.1, pval=0.06517318319290906
# Col 79 is statistically significantly different at alpha=0.1, pval=0.03745329774985086
# Col 80 is statistically significantly different at alpha=0.1, pval=0.013482391658496368
# Col 83 is statistically significantly different at alpha=0.1, pval=0.00718066534687339
# Col 90 is statistically significantly different at alpha=0.1, pval=0.03457473502372782
# Total number different was 12, which is 12.0%

# %%
# As it can be observed, as our alpha value is 0.1 and this is a random test over 100 samples, the number of times the
# columns are different is of roughly 10%

# We can see this happens again with other values of alpha
test_columns(0.05)
# Out:
# Col 31 is statistically significantly different at alpha=0.05, pval=0.044042416341466134
# Col 51 is statistically significantly different at alpha=0.05, pval=0.007140344318679064
# Col 58 is statistically significantly different at alpha=0.05, pval=0.02588626092257888
# Col 79 is statistically significantly different at alpha=0.05, pval=0.03745329774985086
# Col 80 is statistically significantly different at alpha=0.05, pval=0.013482391658496368
# Col 83 is statistically significantly different at alpha=0.05, pval=0.00718066534687339
# Col 90 is statistically significantly different at alpha=0.05, pval=0.03457473502372782
# Total number different was 7, which is 7.000000000000001%

# %%
# We try the same experiment with a chi squared distribution
df2=pd.DataFrame([np.random.chisquare(df=1, size=100) for x in range(100)])
test_columns()
# Out:
# Col 0 is statistically significantly different at alpha=0.1, pval=0.03951201661024284
# Col 1 is statistically significantly different at alpha=0.1, pval=0.004389353195341004
# Col 3 is statistically significantly different at alpha=0.1, pval=0.0011724395290818206
# Col 4 is statistically significantly different at alpha=0.1, pval=2.4282066806883463e-05
# Col 5 is statistically significantly different at alpha=0.1, pval=0.022138722403428672
# Col 6 is statistically significantly different at alpha=0.1, pval=0.015078032479012701
# Col 7 is statistically significantly different at alpha=0.1, pval=8.581330107553512e-05
# Col 8 is statistically significantly different at alpha=0.1, pval=4.1075977093934194e-05
# Col 9 is statistically significantly different at alpha=0.1, pval=5.231271870680809e-05
# Col 10 is statistically significantly different at alpha=0.1, pval=3.670651850951761e-06
# Col 11 is statistically significantly different at alpha=0.1, pval=0.00016922736321794304
# Col 12 is statistically significantly different at alpha=0.1, pval=0.001357620098323521
# Col 13 is statistically significantly different at alpha=0.1, pval=0.00532455142375981
# Col 14 is statistically significantly different at alpha=0.1, pval=0.00044160388486562895
# Col 15 is statistically significantly different at alpha=0.1, pval=0.002542178779496255
# Col 16 is statistically significantly different at alpha=0.1, pval=0.005004575709019597
# Col 17 is statistically significantly different at alpha=0.1, pval=1.0226794151863799e-05
# Col 18 is statistically significantly different at alpha=0.1, pval=8.579145955712492e-08
# Col 19 is statistically significantly different at alpha=0.1, pval=0.0011088180020875525
# Col 20 is statistically significantly different at alpha=0.1, pval=0.0003985585339753878
# Col 21 is statistically significantly different at alpha=0.1, pval=0.0035120905065843936
# Col 22 is statistically significantly different at alpha=0.1, pval=3.622578243567822e-05
# Col 23 is statistically significantly different at alpha=0.1, pval=0.005162620621818552
# Col 24 is statistically significantly different at alpha=0.1, pval=0.0013817433512735581
# Col 25 is statistically significantly different at alpha=0.1, pval=1.1485849318647425e-06
# Col 26 is statistically significantly different at alpha=0.1, pval=5.737977470832193e-05
# Col 27 is statistically significantly different at alpha=0.1, pval=0.0009473107167784742
# Col 28 is statistically significantly different at alpha=0.1, pval=4.172507133840831e-05
# Col 29 is statistically significantly different at alpha=0.1, pval=4.337494150310493e-06
# Col 30 is statistically significantly different at alpha=0.1, pval=0.008663209834391278
# Col 31 is statistically significantly different at alpha=0.1, pval=0.00014519886958109908
# Col 32 is statistically significantly different at alpha=0.1, pval=1.7147789363715933e-05
# Col 33 is statistically significantly different at alpha=0.1, pval=0.0016056953191627109
# Col 34 is statistically significantly different at alpha=0.1, pval=0.00022648168842945765
# Col 35 is statistically significantly different at alpha=0.1, pval=0.00047820973054657696
# Col 36 is statistically significantly different at alpha=0.1, pval=1.933586454021615e-05
# Col 37 is statistically significantly different at alpha=0.1, pval=1.67236584059059e-05
# Col 38 is statistically significantly different at alpha=0.1, pval=0.0020525277962499425
# Col 39 is statistically significantly different at alpha=0.1, pval=0.004521282004074755
# Col 40 is statistically significantly different at alpha=0.1, pval=4.807650849350777e-05
# Col 41 is statistically significantly different at alpha=0.1, pval=0.005584148495139185
# Col 42 is statistically significantly different at alpha=0.1, pval=0.014347956420647654
# Col 43 is statistically significantly different at alpha=0.1, pval=8.812510086853835e-05
# Col 44 is statistically significantly different at alpha=0.1, pval=1.5885480112562247e-05
# Col 45 is statistically significantly different at alpha=0.1, pval=0.0021717442753829705
# Col 46 is statistically significantly different at alpha=0.1, pval=0.0003590957322563215
# Col 47 is statistically significantly different at alpha=0.1, pval=0.00012441149560058848
# Col 48 is statistically significantly different at alpha=0.1, pval=0.0003990390842949013
# Col 49 is statistically significantly different at alpha=0.1, pval=0.0015313629048825915
# Col 50 is statistically significantly different at alpha=0.1, pval=0.005939068504944802
# Col 51 is statistically significantly different at alpha=0.1, pval=4.288501702570225e-05
# Col 52 is statistically significantly different at alpha=0.1, pval=0.00013247807420390067
# Col 53 is statistically significantly different at alpha=0.1, pval=0.0002946261850050814
# Col 54 is statistically significantly different at alpha=0.1, pval=0.0007418512403140018
# Col 55 is statistically significantly different at alpha=0.1, pval=0.001732335562385295
# Col 56 is statistically significantly different at alpha=0.1, pval=0.001779974936218397
# Col 57 is statistically significantly different at alpha=0.1, pval=0.0019651710748293592
# Col 58 is statistically significantly different at alpha=0.1, pval=6.439876173201919e-06
# Col 59 is statistically significantly different at alpha=0.1, pval=5.3833100279788004e-05
# Col 60 is statistically significantly different at alpha=0.1, pval=0.00010864281750655524
# Col 61 is statistically significantly different at alpha=0.1, pval=0.0008545615441406094
# Col 62 is statistically significantly different at alpha=0.1, pval=0.06022452725664144
# Col 63 is statistically significantly different at alpha=0.1, pval=9.45133692742397e-06
# Col 64 is statistically significantly different at alpha=0.1, pval=3.242045189251751e-05
# Col 65 is statistically significantly different at alpha=0.1, pval=3.3099700712820095e-06
# Col 66 is statistically significantly different at alpha=0.1, pval=0.0009527507910581539
# Col 67 is statistically significantly different at alpha=0.1, pval=0.0010725780396460365
# Col 68 is statistically significantly different at alpha=0.1, pval=0.004414318613306522
# Col 69 is statistically significantly different at alpha=0.1, pval=0.0001638608524462634
# Col 70 is statistically significantly different at alpha=0.1, pval=6.755142971460233e-07
# Col 71 is statistically significantly different at alpha=0.1, pval=2.1536854907495868e-05
# Col 72 is statistically significantly different at alpha=0.1, pval=0.0004060398413400323
# Col 73 is statistically significantly different at alpha=0.1, pval=0.0014222986632786074
# Col 74 is statistically significantly different at alpha=0.1, pval=0.0007161396179490481
# Col 75 is statistically significantly different at alpha=0.1, pval=0.0001513378113700768
# Col 76 is statistically significantly different at alpha=0.1, pval=0.0002730940017293319
# Col 77 is statistically significantly different at alpha=0.1, pval=3.6868687247523565e-05
# Col 78 is statistically significantly different at alpha=0.1, pval=0.01096178500478499
# Col 79 is statistically significantly different at alpha=0.1, pval=0.02248300280584514
# Col 80 is statistically significantly different at alpha=0.1, pval=0.0024185799926184173
# Col 81 is statistically significantly different at alpha=0.1, pval=0.0004944924419846338
# Col 82 is statistically significantly different at alpha=0.1, pval=0.033107404206988426
# Col 83 is statistically significantly different at alpha=0.1, pval=0.00011438747262619677
# Col 84 is statistically significantly different at alpha=0.1, pval=0.0002109264414510057
# Col 85 is statistically significantly different at alpha=0.1, pval=5.613902021723086e-05
# Col 86 is statistically significantly different at alpha=0.1, pval=0.0005891101036573593
# Col 87 is statistically significantly different at alpha=0.1, pval=0.00173319995018917
# Col 88 is statistically significantly different at alpha=0.1, pval=0.0004015464835787773
# Col 89 is statistically significantly different at alpha=0.1, pval=3.238668467271215e-05
# Col 90 is statistically significantly different at alpha=0.1, pval=0.006097179029610114
# Col 91 is statistically significantly different at alpha=0.1, pval=0.00041632635332035795
# Col 92 is statistically significantly different at alpha=0.1, pval=7.296777843937253e-05
# Col 93 is statistically significantly different at alpha=0.1, pval=9.371666936300548e-06
# Col 94 is statistically significantly different at alpha=0.1, pval=0.014579418889620012
# Col 95 is statistically significantly different at alpha=0.1, pval=0.0038591399208653364
# Col 96 is statistically significantly different at alpha=0.1, pval=0.0030679564302722104
# Col 97 is statistically significantly different at alpha=0.1, pval=0.0010032931797787118
# Col 98 is statistically significantly different at alpha=0.1, pval=2.930809162748782e-06
# Col 99 is statistically significantly different at alpha=0.1, pval=0.0008708598969071842
# Total number different was 99, which is 99.0%
